# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
from nba_api.stats.static import teams
from multiprocessing import Pool
from concurrent.futures import ProcessPoolExecutor
from joblib import Parallel, delayed

# %%
career = playercareerstats.PlayerCareerStats(player_id='203999')

career.get_data_frames()[0]

all_players_ids = [id['id'] for id in players.get_active_players()]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 career = playercareerstats.PlayerCareerStats(player_id='203999')
#       3 career.get_data_frames()[0]
#       5 all_players_ids = [id['id'] for id in players.get_active_players()]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
#     312     "LeagueID": league_id_nullable,
#     313 }
#     314 if get_request:
# --> 315     self.get_request()
#
# ...

# %%
def get_player_dataframe(id):
    df = playercareerstats.PlayerCareerStats(player_id=id).get_data_frames()[0]
    return df

# %%
df = playercareerstats.PlayerCareerStats(player_id=all_player_ids[2]).get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = playercareerstats.PlayerCareerStats(player_id=all_player_ids[2]).get_data_frames()[0]
#
# NameError: name 'all_player_ids' is not defined

# %%
get_player_dataframe(all_player_ids[300])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 get_player_dataframe(all_player_ids[300])
#
# Cell In[64], line 2, in get_player_dataframe(id)
#       1 def get_player_dataframe(id):
# ----> 2     df = playercareerstats.PlayerCareerStats(player_id=id).get_data_frames()[0]
#       3     return df
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
#     312     "LeagueID": league_id_nullable,
#     313 }
#     314 if get_request:
# --> 315     self.get_request()
#
# ...

# %%
x = get_player_dataframe(1628389)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 x = get_player_dataframe(1628389)
#
# Cell In[64], line 2, in get_player_dataframe(id)
#       1 def get_player_dataframe(id):
# ----> 2     df = playercareerstats.PlayerCareerStats(player_id=id).get_data_frames()[0]
#       3     return df
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
#     312     "LeagueID": league_id_nullable,
#     313 }
#     314 if get_request:
# --> 315     self.get_request()
#
# ...

# %%
id = players.find_players_by_full_name('Lebron')
id[0]['first_name']
# Out:
# 'LeBron'

# %%
def get_player_id(player_name):
    id = players.find_players_by_full_name(player_name)[0]['id']
    return id

# %%
def rank_players_on_team(team_name, criteria):
    team_id = teams.find_teams_by_full_name(team_name)['id']
# Out:
# 203999

# %%
teams.find_teams_by_full_name('Denver Nuggets')
# Out:
# [{'id': 1610612743,
#   'full_name': 'Denver Nuggets',
#   'abbreviation': 'DEN',
#   'nickname': 'Nuggets',
#   'city': 'Denver',
#   'state': 'Colorado',
#   'year_founded': 1976}]

# %%
id = 1630173
on_team = [player for player in players.get_active_players() if player['id'] == id]

# %%
all_player_ids = [id['id'] for id in players.get_active_players()]

# %%
all_player_ids
# Out:
# [1630173,
#  203500,
#  1628389,
#  1630534,
#  1630583,
#  1629638,
#  1628960,
#  1628386,
#  1630631,
#  203937,
#  203507,
#  203648,
#  1630175,
#  1628384,
#  1627853,
#  1630166,
#  1629028,
#  1628962,
#  1628963,
#  1641735,
#  1631116,
#  1630163,
#  1628366,
#  1628964,
#  1631094,
#  1630217,
#  1630625,
#  1631230,
#  203084,
#  1630567,
#  1629628,
#  1629646,
#  1641734,
#  1628966,
#  201587,
#  203078,
#  1627736,
#  1630699,
#  1641777,
#  202722,
#  201976,
#  1630180,
#  1629048,
#  1641931,
#  202687,
#  1641710,
#  1641778,
#  203992,
#  202711,
#  1629626,
#  1629716,
#  1626164,
#  1630527,
#  1628449,
#  1630547,
#  1631103,
#  1631128,
#  1628969,
#  1628970,
#  1629052,
#  1627763,
#  1629717,
#  1628415,
#  1628971,
#  1627759,
#  1631112,
#  1641738,
#  1629650,
#  1630535,
#  1629718,
#  1628972,
#  1628973,
#  1628418,
#  1641723,
#  203493,
#  202692,
#  1630215,
#  202710,
#  1631219,
#  1631288,
#  203484,
#  1641739,
#  1628427,
#  203991,
# ...

# %%
with ProcessPoolExecutor() as executor:
    results = executor.map(get_player_dataframe, all_player_ids)
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# ...

# %%
results = Parallel(n_jobs=4)(delayed(get_player_dataframe)(id) for id in all_player_ids[:5])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 results = Parallel(n_jobs=4)(delayed(get_player_dataframe)(id) for id in all_player_ids[:5])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
# ...

# %%
with Pool(processes=4) as pool:
    all_data_frames = pool.map(get_player_dataframe, all_players_ids[:5])
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# ...

# %%
all_data_frames = playercareerstats.PlayerCareerStats(player_id=all_player_ids[300]).get_data_frames()[0]

# %%
all_data_frames
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      202083   2009-10        00  1610612762               UTA        23.0
# 1      202083   2010-11        00  1610612757               POR        24.0
# 2      202083   2011-12        00  1610612757               POR        25.0
# 3      202083   2012-13        00  1610612757               POR        26.0
# 4      202083   2013-14        00  1610612757               POR        27.0
# 5      202083   2014-15        00  1610612757               POR        28.0
# 6      202083   2015-16        00  1610612742               DAL        29.0
# 7      202083   2016-17        00  1610612742               DAL        30.0
# 8      202083   2017-18        00  1610612742               DAL        31.0
# 9      202083   2018-19        00  1610612742               DAL        32.0
# 10     202083   2018-19        00  1610612752               NYK        32.0
# ...

# %%
all_data_frames = [get_player_dataframe(id) for id in all_players_ids[:10]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 all_data_frames = [get_player_dataframe(id) for id in all_players_ids[:10]]
#
# Cell In[62], line 1, in <listcomp>(.0)
# ----> 1 all_data_frames = [get_player_dataframe(id) for id in all_players_ids[:10]]
#
# Cell In[34], line 2, in get_player_dataframe(player_id)
#       1 def get_player_dataframe(player_id):
# ----> 2     df = playercareerstats.PlayerCareerStats(player_id=player_id).get_data_frames()[0]
#       3     return df
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/nba_api/stats/endpoints/playercareerstats.py:315, in PlayerCareerStats.__init__(self, player_id, per_mode36, league_id_nullable, proxy, headers, timeout, get_request)
#     309 self.parameters = {
#     310     "PlayerID": player_id,
#     311     "PerMode": per_mode36,
# ...

# %%
all_data_frames
# Out:
# [<function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
#  <function __main__.get_player_dataframe(player_id)>,
# ...

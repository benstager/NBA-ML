# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
from nba_api.stats.static import teams
from multiprocessing import Pool
from concurrent.futures import ProcessPoolExecutor
from joblib import Parallel, delayed

# %%
all_player_ids = [id['id'] for id in players.get_active_players()]

# %%
def get_player_dataframe(id):
    df = playercareerstats.PlayerCareerStats(id).get_data_frames()[0]
    return df

# %%
df = playercareerstats.PlayerCareerStats(player_id=all_player_ids[2]).get_data_frames()[0]

# %%
results = Parallel(n_jobs=4)(delayed(get_player_dataframe)(id) for id in all_player_ids[:5])

# %%
with ProcessPoolExecutor() as executor:
    results = executor.map(get_player_dataframe, all_player_ids[:5])
# Out:
# Process SpawnProcess-23:
# Process SpawnProcess-25:
# Process SpawnProcess-24:
# Process SpawnProcess-26:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
# ...

# %%
pool = Pool(processes=4)
all_data_frames = pool.map(get_player_dataframe, all_player_ids[:5])
# Out:
# Process SpawnPoolWorker-46:
# Process SpawnPoolWorker-45:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'get_player_dataframe' on <module '__main__' (built-in)>
# ...

# %%
from multiprocessing import Pool

def get_player_dataframe(id):
    df = playercareerstats.PlayerCareerStats(id).get_data_frames()[0]
    return df

def main():
    with ProcessPoolExecutor() as executor:
        results = executor.map(get_player_dataframe, all_player_ids[:10])

if __name__ == "__main__":
    main()
# Out:
# Process SpawnProcess-66:
# Process SpawnProcess-63:
# Process SpawnProcess-64:
# Process SpawnProcess-65:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# ...
